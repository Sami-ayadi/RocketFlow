# %%
import pandas as pd

# %%
import psycopg2
from psycopg2.extras import execute_values

# %%
sattelites_types = {
    'name': 'string',
    'operator': 'string',
    'country_of_operator': 'string',
    'contractor': 'string',
    'country_of_contractor': 'string',
    'purpose': 'string',
    'users': 'string',
    'date_of_launch': 'string' ,
    'class_of_orbit': 'string',
    'orbit_period': 'float64',
    'launch_mass': 'float64',
    'Date of Launch': 'string',
    'expected_lifetime': 'float64',
    'launch_site': 'string',
    'rocket_name': 'string'
}
sattelites_df = pd.read_excel("../data/standardized_data/sattelites.xlsx",dtype=sattelites_types)

# %%
launches_df= pd.read_excel("../data/standardized_data/launches.xlsx")

# %%
rocket_types = {
    'name': 'string',
    'company': 'string',
    'status': 'string',
    'liftoff_thrust Thrust': 'float64',
    'payload_leo': 'float64',
    'stages': 'object',
    'height': 'float64',
    'price': 'float64',
}
rockets_df= pd.read_excel("../data/extracted_data/rockets.xlsx",dtype=rocket_types)

# %%
satellite_counts = sattelites_df.groupby(["date_of_launch", "launch_site","rocket_name"]).size().reset_index(name="satellite_count")

# %%
dff = satellite_counts[satellite_counts["satellite_count"]>1].sort_values(by="satellite_count", ascending=False)

# %%
# 2. Connect to PostgreSQL
conn = psycopg2.connect(
    dbname="space_dw",
    user="postgres",
    password="postgres",
    host="localhost",
    port="5433"
)
cur = conn.cursor()
conn.rollback()
cur.execute("SELECT 1;")

# %%
# 3. Prepare Dimension Tables
launch_site_dim = launches_df[['space_port', 'country']].drop_duplicates()
rocket_dim = rockets_df[['name', 'company', 'status', 'liftoff_thrust', 'payload_leo', 'stages', 'height', 'price']].drop_duplicates()
rocket_dim = rocket_dim.where(pd.notnull(rocket_dim), None)
launch_dim = launches_df[['status', 'provider', 'mission','launch_pad']].drop_duplicates()
satellite_dim = sattelites_df[['name', 'country_of_operator', 'operator', 'users', 'purpose', 'class_of_orbit', 'orbit_period', 'launch_mass', 'expected_lifetime', 'contractor', 'country_of_contractor']].drop_duplicates()
satellite_dim = satellite_dim.where(pd.notnull(satellite_dim), None)

# %%
date_dim = pd.DataFrame()
date_dim['full_date'] = pd.to_datetime(launches_df['date']).drop_duplicates()
date_dim['year'] = date_dim['full_date'].dt.year
date_dim['month'] = date_dim['full_date'].dt.month
date_dim['day'] = date_dim['full_date'].dt.day

# %%
# 4. Insert Dimensions (Bulk Insert)
def bulk_insert_dim(table, df, returning_key):    
    records = [tuple(x) for x in df.to_numpy()]
    columns = ','.join(df.columns)
    placeholders = ','.join(['%s'] * len(df.columns))
    
    insert_sql = f"INSERT INTO {table} ({columns}) VALUES ({placeholders}) ON CONFLICT DO NOTHING RETURNING {returning_key};"
    keys = []
    for row in records:
        cur.execute(insert_sql, row)
        res = cur.fetchone()
        if res:
            keys.append(res[0])
    return keys

# %%
satellite_dim['country_of_contractor'] = satellite_dim['country_of_contractor'].apply(
    lambda x: x if isinstance(x, list) else [x]
)
satellite_dim['country_of_operator'] = satellite_dim['country_of_operator'].apply(
    lambda x: x if isinstance(x, list) else [x]
)

# %%
# Insert dimensions
bulk_insert_dim('dim_launch_site', launch_site_dim, 'launch_site_key')
bulk_insert_dim('dim_rocket', rocket_dim, 'rocket_key')
bulk_insert_dim('dim_satellite', satellite_dim, 'satellite_key')
bulk_insert_dim('dim_launch_site', launch_site_dim.head(1), 'launch_site_key')
bulk_insert_dim('dim_date', date_dim, 'date_key')
# Out:
# [23821,
#  23822,
#  23823,
#  23824,
#  23825,
#  23826,
#  23827,
#  23828,
#  23829,
#  23830,
#  23831,
#  23832,
#  23833,
#  23834,
#  23835,
#  23836,
#  23837,
#  23838,
#  23839,
#  23840,
#  23841,
#  23842,
#  23843,
#  23844,
#  23845,
#  23846,
#  23847,
#  23848,
#  23849,
#  23850,
#  23851,
#  23852,
#  23853,
#  23854,
#  23855,
#  23856,
#  23857,
#  23858,
#  23859,
#  23860,
#  23861,
#  23862,
#  23863,
#  23864,
#  23865,
#  23866,
#  23867,
#  23868,
#  23869,
#  23870,
#  23871,
#  23872,
#  23873,
#  23874,
#  23875,
#  23876,
#  23877,
#  23878,
#  23879,
#  23880,
#  23881,
#  23882,
#  23883,
#  23884,
#  23885,
#  23886,
#  23887,
#  23888,
#  23889,
#  23890,
#  23891,
#  23892,
#  23893,
#  23894,
#  23895,
#  23896,
#  23897,
#  23898,
#  23899,
#  23900,
#  23901,
#  23902,
#  23903,
#  23904,
#  23905,
#  23906,
#  23907,
#  23908,
#  23909,
#  23910,
#  23911,
#  23912,
#  23913,
#  23914,
#  23915,
#  23916,
#  23917,
#  23918,
#  23919,
#  23920,
#  23921,
#  23922,
#  23923,
#  23924,
#  23925,
#  23926,
#  23927,
#  23928,
#  23929,
#  23930,
#  23931,
#  23932,
#  23933,
#  23934,
#  23935,
#  23936,
#  23937,
#  23938,
#  23939,
#  23940,
#  23941,
#  23942,
#  23943,
#  23944,
#  23945,
#  23946,
#  23947,
#  23948,
#  23949,
#  23950,
#  23951,
#  23952,
#  23953,
#  23954,
#  23955,
#  23956,
#  23957,
#  23958,
#  23959,
#  23960,
#  23961,
#  23962,
#  23963,
#  23964,
#  23965,
#  23966,
#  23967,
#  23968,
#  23969,
#  23970,
#  23971,
#  23972,
#  23973,
#  23974,
#  23975,
#  23976,
#  23977,
#  23978,
#  23979,
#  23980,
#  23981,
#  23982,
#  23983,
#  23984,
#  23985,
#  23986,
#  23987,
#  23988,
#  23989,
#  23990,
#  23991,
#  23992,
#  23993,
#  23994,
#  23995,
#  23996,
#  23997,
#  23998,
#  23999,
#  24000,
#  24001,
#  24002,
#  24003,
#  24004,
#  24005,
#  24006,
#  24007,
#  24008,
#  24009,
#  24010,
#  24011,
#  24012,
#  24013,
#  24014,
#  24015,
#  24016,
#  24017,
#  24018,
#  24019,
#  24020,
#  24021,
#  24022,
#  24023,
#  24024,
#  24025,
#  24026,
#  24027,
#  24028,
#  24029,
#  24030,
#  24031,
#  24032,
#  24033,
#  24034,
#  24035,
#  24036,
#  24037,
#  24038,
#  24039,
#  24040,
#  24041,
#  24042,
#  24043,
#  24044,
#  24045,
#  24046,
#  24047,
#  24048,
#  24049,
#  24050,
#  24051,
#  24052,
#  24053,
#  24054,
#  24055,
#  24056,
#  24057,
#  24058,
#  24059,
#  24060,
#  24061,
#  24062,
#  24063,
#  24064,
#  24065,
#  24066,
#  24067,
#  24068,
#  24069,
#  24070,
#  24071,
#  24072,
#  24073,
#  24074,
#  24075,
#  24076,
#  24077,
#  24078,
#  24079,
#  24080,
#  24081,
#  24082,
#  24083,
#  24084,
#  24085,
#  24086,
#  24087,
#  24088,
#  24089,
#  24090,
#  24091,
#  24092,
#  24093,
#  24094,
#  24095,
#  24096,
#  24097,
#  24098,
#  24099,
#  24100,
#  24101,
#  24102,
#  24103,
#  24104,
#  24105,
#  24106,
#  24107,
#  24108,
#  24109,
#  24110,
#  24111,
#  24112,
#  24113,
#  24114,
#  24115,
#  24116,
#  24117,
#  24118,
#  24119,
#  24120,
#  24121,
#  24122,
#  24123,
#  24124,
#  24125,
#  24126,
#  24127,
#  24128,
#  24129,
#  24130,
#  24131,
#  24132,
#  24133,
#  24134,
#  24135,
#  24136,
#  24137,
#  24138,
#  24139,
#  24140,
#  24141,
#  24142,
#  24143,
#  24144,
#  24145,
#  24146,
#  24147,
#  24148,
#  24149,
#  24150,
#  24151,
#  24152,
#  24153,
#  24154,
#  24155,
#  24156,
#  24157,
#  24158,
#  24159,
#  24160,
#  24161,
#  24162,
#  24163,
#  24164,
#  24165,
#  24166,
#  24167,
#  24168,
#  24169,
#  24170,
#  24171,
#  24172,
#  24173,
#  24174,
#  24175,
#  24176,
#  24177,
#  24178,
#  24179,
#  24180,
#  24181,
#  24182,
#  24183,
#  24184,
#  24185,
#  24186,
#  24187,
#  24188,
#  24189,
#  24190,
#  24191,
#  24192,
#  24193,
#  24194,
#  24195,
#  24196,
#  24197,
#  24198,
#  24199,
#  24200,
#  24201,
#  24202,
#  24203,
#  24204,
#  24205,
#  24206,
#  24207,
#  24208,
#  24209,
#  24210,
#  24211,
#  24212,
#  24213,
#  24214,
#  24215,
#  24216,
#  24217,
#  24218,
#  24219,
#  24220,
#  24221,
#  24222,
#  24223,
#  24224,
#  24225,
#  24226,
#  24227,
#  24228,
#  24229,
#  24230,
#  24231,
#  24232,
#  24233,
#  24234,
#  24235,
#  24236,
#  24237,
#  24238,
#  24239,
#  24240,
#  24241,
#  24242,
#  24243,
#  24244,
#  24245,
#  24246,
#  24247,
#  24248,
#  24249,
#  24250,
#  24251,
#  24252,
#  24253,
#  24254,
#  24255,
#  24256,
#  24257,
#  24258,
#  24259,
#  24260,
#  24261,
#  24262,
#  24263,
#  24264,
#  24265,
#  24266,
#  24267,
#  24268,
#  24269,
#  24270,
#  24271,
#  24272,
#  24273,
#  24274,
#  24275,
#  24276,
#  24277,
#  24278,
#  24279,
#  24280,
#  24281,
#  24282,
#  24283,
#  24284,
#  24285,
#  24286,
#  24287,
#  24288,
#  24289,
#  24290,
#  24291,
#  24292,
#  24293,
#  24294,
#  24295,
#  24296,
#  24297,
#  24298,
#  24299,
#  24300,
#  24301,
#  24302,
#  24303,
#  24304,
#  24305,
#  24306,
#  24307,
#  24308,
#  24309,
#  24310,
#  24311,
#  24312,
#  24313,
#  24314,
#  24315,
#  24316,
#  24317,
#  24318,
#  24319,
#  24320,
#  24321,
#  24322,
#  24323,
#  24324,
#  24325,
#  24326,
#  24327,
#  24328,
#  24329,
#  24330,
#  24331,
#  24332,
#  24333,
#  24334,
#  24335,
#  24336,
#  24337,
#  24338,
#  24339,
#  24340,
#  24341,
#  24342,
#  24343,
#  24344,
#  24345,
#  24346,
#  24347,
#  24348,
#  24349,
#  24350,
#  24351,
#  24352,
#  24353,
#  24354,
#  24355,
#  24356,
#  24357,
#  24358,
#  24359,
#  24360,
#  24361,
#  24362,
#  24363,
#  24364,
#  24365,
#  24366,
#  24367,
#  24368,
#  24369,
#  24370,
#  24371,
#  24372,
#  24373,
#  24374,
#  24375,
#  24376,
#  24377,
#  24378,
#  24379,
#  24380,
#  24381,
#  24382,
#  24383,
#  24384,
#  24385,
#  24386,
#  24387,
#  24388,
#  24389,
#  24390,
#  24391,
#  24392,
#  24393,
#  24394,
#  24395,
#  24396,
#  24397,
#  24398,
#  24399,
#  24400,
#  24401,
#  24402,
#  24403,
#  24404,
#  24405,
#  24406,
#  24407,
#  24408,
#  24409,
#  24410,
#  24411,
#  24412,
#  24413,
#  24414,
#  24415,
#  24416,
#  24417,
#  24418,
#  24419,
#  24420,
#  24421,
#  24422,
#  24423,
#  24424,
#  24425,
#  24426,
#  24427,
#  24428,
#  24429,
#  24430,
#  24431,
#  24432,
#  24433,
#  24434,
#  24435,
#  24436,
#  24437,
#  24438,
#  24439,
#  24440,
#  24441,
#  24442,
#  24443,
#  24444,
#  24445,
#  24446,
#  24447,
#  24448,
#  24449,
#  24450,
#  24451,
#  24452,
#  24453,
#  24454,
#  24455,
#  24456,
#  24457,
#  24458,
#  24459,
#  24460,
#  24461,
#  24462,
#  24463,
#  24464,
#  24465,
#  24466,
#  24467,
#  24468,
#  24469,
#  24470,
#  24471,
#  24472,
#  24473,
#  24474,
#  24475,
#  24476,
#  24477,
#  24478,
#  24479,
#  24480,
#  24481,
#  24482,
#  24483,
#  24484,
#  24485,
#  24486,
#  24487,
#  24488,
#  24489,
#  24490,
#  24491,
#  24492,
#  24493,
#  24494,
#  24495,
#  24496,
#  24497,
#  24498,
#  24499,
#  24500,
#  24501,
#  24502,
#  24503,
#  24504,
#  24505,
#  24506,
#  24507,
#  24508,
#  24509,
#  24510,
#  24511,
#  24512,
#  24513,
#  24514,
#  24515,
#  24516,
#  24517,
#  24518,
#  24519,
#  24520,
#  24521,
#  24522,
#  24523,
#  24524,
#  24525,
#  24526,
#  24527,
#  24528,
#  24529,
#  24530,
#  24531,
#  24532,
#  24533,
#  24534,
#  24535,
#  24536,
#  24537,
#  24538,
#  24539,
#  24540,
#  24541,
#  24542,
#  24543,
#  24544,
#  24545,
#  24546,
#  24547,
#  24548,
#  24549,
#  24550,
#  24551,
#  24552,
#  24553,
#  24554,
#  24555,
#  24556,
#  24557,
#  24558,
#  24559,
#  24560,
#  24561,
#  24562,
#  24563,
#  24564,
#  24565,
#  24566,
#  24567,
#  24568,
#  24569,
#  24570,
#  24571,
#  24572,
#  24573,
#  24574,
#  24575,
#  24576,
#  24577,
#  24578,
#  24579,
#  24580,
#  24581,
#  24582,
#  24583,
#  24584,
#  24585,
#  24586,
#  24587,
#  24588,
#  24589,
#  24590,
#  24591,
#  24592,
#  24593,
#  24594,
#  24595,
#  24596,
#  24597,
#  24598,
#  24599,
#  24600,
#  24601,
#  24602,
#  24603,
#  24604,
#  24605,
#  24606,
#  24607,
#  24608,
#  24609,
#  24610,
#  24611,
#  24612,
#  24613,
#  24614,
#  24615,
#  24616,
#  24617,
#  24618,
#  24619,
#  24620,
#  24621,
#  24622,
#  24623,
#  24624,
#  24625,
#  24626,
#  24627,
#  24628,
#  24629,
#  24630,
#  24631,
#  24632,
#  24633,
#  24634,
#  24635,
#  24636,
#  24637,
#  24638,
#  24639,
#  24640,
#  24641,
#  24642,
#  24643,
#  24644,
#  24645,
#  24646,
#  24647,
#  24648,
#  24649,
#  24650,
#  24651,
#  24652,
#  24653,
#  24654,
#  24655,
#  24656,
#  24657,
#  24658,
#  24659,
#  24660,
#  24661,
#  24662,
#  24663,
#  24664,
#  24665,
#  24666,
#  24667,
#  24668,
#  24669,
#  24670,
#  24671,
#  24672,
#  24673,
#  24674,
#  24675,
#  24676,
#  24677,
#  24678,
#  24679,
#  24680,
#  24681,
#  24682,
#  24683,
#  24684,
#  24685,
#  24686,
#  24687,
#  24688,
#  24689,
#  24690,
#  24691,
#  24692,
#  24693,
#  24694,
#  24695,
#  24696,
#  24697,
#  24698,
#  24699,
#  24700,
#  24701,
#  24702,
#  24703,
#  24704,
#  24705,
#  24706,
#  24707,
#  24708,
#  24709,
#  24710,
#  24711,
#  24712,
#  24713,
#  24714,
#  24715,
#  24716,
#  24717,
#  24718,
#  24719,
#  24720,
#  24721,
#  24722,
#  24723,
#  24724,
#  24725,
#  24726,
#  24727,
#  24728,
#  24729,
#  24730,
#  24731,
#  24732,
#  24733,
#  24734,
#  24735,
#  24736,
#  24737,
#  24738,
#  24739,
#  24740,
#  24741,
#  24742,
#  24743,
#  24744,
#  24745,
#  24746,
#  24747,
#  24748,
#  24749,
#  24750,
#  24751,
#  24752,
#  24753,
#  24754,
#  24755,
#  24756,
#  24757,
#  24758,
#  24759,
#  24760,
#  24761,
#  24762,
#  24763,
#  24764,
#  24765,
#  24766,
#  24767,
#  24768,
#  24769,
#  24770,
#  24771,
#  24772,
#  24773,
#  24774,
#  24775,
#  24776,
#  24777,
#  24778,
#  24779,
#  24780,
#  24781,
#  24782,
#  24783,
#  24784,
#  24785,
#  24786,
#  24787,
#  24788,
#  24789,
#  24790,
#  24791,
#  24792,
#  24793,
#  24794,
#  24795,
#  24796,
#  24797,
#  24798,
#  24799,
#  24800,
#  24801,
#  24802,
#  24803,
#  24804,
#  24805,
#  24806,
#  24807,
#  24808,
#  24809,
#  24810,
#  24811,
#  24812,
#  24813,
#  24814,
#  24815,
#  24816,
#  24817,
#  24818,
#  24819,
#  24820,
#  ...]

# %%
conn.commit()

# %%
# Merge satellites with launches (using rocket, launch_site, date)
sattelites_df['date_of_launch'] = pd.to_datetime(sattelites_df['date_of_launch'])
merged_df = sattelites_df.merge(
    launches_df,
    left_on=['date_of_launch', 'rocket_name', 'launch_site'],
    right_on=['date', 'rocket', 'space_port'],
    how='inner'
)

# %%
merged_df
# Out:
#                          name country_of_operator  \
# 0     AAC AIS-Sat1 (Kelpie 1)  ['United Kingdom']
# 1                       ABS-2   ['Multinational']
# 2                      ABS-2A   ['Multinational']
# 3                     ADLER-2         ['Austria']
# 4                     USA 223             ['USA']
# ...                       ...                 ...
# 3338                    OHS-6           ['China']
# 3339                    OHS-7           ['China']
# 3340                    OHS-8           ['China']
# 3341                    OVS-3           ['China']
# 3342               Ziyuan 3-2           ['China']
#
#                                                operator       users  \
# 0                                       AAC Clyde Space  Commercial
# 1                         Asia Broadcast Satellite Ltd.  Commercial
# 2                         Asia Broadcast Satellite Ltd.  Commercial
# 3                     Austrian Space Forum (OEWF)/Spire       Civil
# 4                  National Reconnaissance Office (NRO)    Military
# ...                                                 ...         ...
# 3338         Zhuhai Orbita Control Engineering Co. Ltd.  Commercial
# 3339         Zhuhai Orbita Control Engineering Co. Ltd.  Commercial
# 3340         Zhuhai Orbita Control Engineering Co. Ltd.  Commercial
# 3341         Zhuhai Orbita Control Engineering Co. Ltd.  Commercial
# 3342  China Centre for Resources Satellite Data and ...  Government
#
#                 purpose class_of_orbit  orbit_period  launch_mass  \
# 0     Earth Observation            LEO         95.00          4.0
# 1        Communications            GEO       1436.03       6330.0
# 2        Communications            GEO       1436.10       1800.0
# 3         Earth Science            LEO         95.00         11.5
# 4     Earth Observation            GEO       1436.00       5000.0
# ...                 ...            ...           ...          ...
# 3338  Earth Observation            LEO         94.60         55.0
# 3339  Earth Observation            LEO         94.60         55.0
# 3340  Earth Observation            LEO         94.60         55.0
# 3341  Earth Observation            LEO         94.60         55.0
# 3342  Earth Observation            LEO         94.49       2630.0
#
#      date_of_launch  expected_lifetime  ...     rocket_name       date  \
# 0        2023-01-03                NaN  ...        Falcon 9 2023-01-03
# 1        2014-02-06               15.0  ...    Ariane 5 ECA 2014-02-06
# 2        2016-06-15               15.0  ...        Falcon 9 2016-06-15
# 3        2023-04-15                NaN  ...        Falcon 9 2023-04-15
# 4        2010-11-21                NaN  ...  Delta IV Heavy 2010-11-21
# ...             ...                ...  ...             ...        ...
# 3338     2019-09-19                NaN  ...   Long March 11 2019-09-19
# 3339     2019-09-19                NaN  ...   Long March 11 2019-09-19
# 3340     2019-09-19                NaN  ...   Long March 11 2019-09-19
# 3341     2019-09-19                NaN  ...   Long March 11 2019-09-19
# 3342     2016-05-29                4.0  ...   Long March 4B 2016-05-29
#
#        status                                           provider  \
# 0     Success                                             SpaceX
# 1     Success                                        Arianespace
# 2     Success                                             SpaceX
# 3     Success                                             SpaceX
# 4     Success                             United Launch Alliance
# ...       ...                                                ...
# 3338  Success  China Aerospace Science and Technology Corpora...
# 3339  Success  China Aerospace Science and Technology Corpora...
# 3340  Success  China Aerospace Science and Technology Corpora...
# 3341  Success  China Aerospace Science and Technology Corpora...
# 3342  Success  China Aerospace Science and Technology Corpora...
#
#                                               mission  \
# 0             Transporter 6 (Dedicated SSO Rideshare)
# 1                                ABS-2 & Athena-Fidus
# 2                        Eutelsat 117 West B & ABS-2A
# 3             Transporter 7 (Dedicated SSO Rideshare)
# 4                          NROL-32 (Mentor) (USA-223)
# ...                                               ...
# 3338                                      Zhuhai-1-03
# 3339                                      Zhuhai-1-03
# 3340                                      Zhuhai-1-03
# 3341                                      Zhuhai-1-03
# 3342  Ziyuan 3-02 & Ã‘uSat-1 & -2 (Fresco and Batata)
#
#                                           launch_site_y  \
# 0     Space Launch Complex 40 | Cape Canaveral, FL, USA
# 1     Ariane Launch Area 3 | Guiana Space Centre, Fr...
# 2     Space Launch Complex 40 | Cape Canaveral, FL, USA
# 3     Space Launch Complex 4E | Vandenberg SFB, CA, USA
# 4     Space Launch Complex 37B | Cape Canaveral, FL,...
# ...                                                 ...
# 3338  Launch Area 95A | Jiuquan Satellite Launch Cen...
# 3339  Launch Area 95A | Jiuquan Satellite Launch Cen...
# 3340  Launch Area 95A | Jiuquan Satellite Launch Cen...
# 3341  Launch Area 95A | Jiuquan Satellite Launch Cen...
# 3342  Launch Complex 9 | Taiyuan Satellite Launch Ce...
#
#                     launch_pad                       space_port  \
# 0      Space Launch Complex 40                   Cape Canaveral
# 1         Ariane Launch Area 3              Guiana Space Centre
# 2      Space Launch Complex 40                   Cape Canaveral
# 3      Space Launch Complex 4E                   Vandenberg SFB
# 4     Space Launch Complex 37B                   Cape Canaveral
# ...                        ...                              ...
# 3338           Launch Area 95A  Jiuquan Satellite Launch Center
# 3339           Launch Area 95A  Jiuquan Satellite Launch Center
# 3340           Launch Area 95A  Jiuquan Satellite Launch Center
# 3341           Launch Area 95A  Jiuquan Satellite Launch Center
# 3342          Launch Complex 9  Taiyuan Satellite Launch Center
#
#             country          rocket
# 0               USA        Falcon 9
# 1     French Guiana    Ariane 5 ECA
# 2               USA        Falcon 9
# 3               USA        Falcon 9
# 4               USA  Delta IV Heavy
# ...             ...             ...
# 3338          China   Long March 11
# 3339          China   Long March 11
# 3340          China   Long March 11
# 3341          China   Long March 11
# 3342          China   Long March 4B
#
# [3343 rows x 23 columns]

# %%
fact_records = []

for _, row in merged_df.iterrows():
    # ----------------------------
    # Dim Satellite
    cur.execute("SELECT satellite_key FROM dim_satellite WHERE name = %s", (row['name'],))
    res = cur.fetchone()
    if res:
        satellite_key = res[0]
    else:
        cur.execute("INSERT INTO dim_satellite (name) VALUES (%s) RETURNING satellite_key", (row['name'],))
        satellite_key = cur.fetchone()[0]

    # ----------------------------
    # Dim Rocket
    cur.execute("SELECT rocket_key FROM dim_rocket WHERE name = %s", (row['rocket_name'],))
    res = cur.fetchone()
    if res:
        rocket_key = res[0]
    else:
        cur.execute("INSERT INTO dim_rocket (name) VALUES (%s) RETURNING rocket_key", (row['rocket_name'],))
        rocket_key = cur.fetchone()[0]

    # ----------------------------
    # Dim Launch Site
    cur.execute("SELECT launch_site_key FROM dim_launch_site WHERE space_port = %s", (row['space_port'],))
    res = cur.fetchone()
    if res:
        launch_site_key = res[0]
    else:
        cur.execute("INSERT INTO dim_launch_site (space_port, country) VALUES (%s, %s) RETURNING launch_site_key",
                    (row['space_port'], row.get('country', 'Unknown')))
        launch_site_key = cur.fetchone()[0]

    # ----------------------------
    # Dim Date
    cur.execute("SELECT date_key FROM dim_date WHERE full_date = %s", (row['date_of_launch'],))
    res = cur.fetchone()
    if res:
        date_key = res[0]
    else:
        cur.execute("INSERT INTO dim_date (full_date) VALUES (%s) RETURNING date_key", (row['date_of_launch'],))
        date_key = cur.fetchone()[0]

    # ----------------------------
    # Dim Launch
    cur.execute("""
        SELECT launch_key FROM dim_launch 
        WHERE status = %s AND provider = %s AND mission = %s
    """, (row['status'], row['provider'], row['mission']))
    res = cur.fetchone()
    if res:
        launch_key = res[0]
    else:
        cur.execute("""
            INSERT INTO dim_launch (status, provider, mission) 
            VALUES (%s, %s, %s) RETURNING launch_key
        """, (row['status'], row['provider'], row['mission']))
        launch_key = cur.fetchone()[0]

    # ----------------------------
    # Append to fact table records
    fact_records.append((satellite_key, rocket_key, launch_site_key, date_key, launch_key))

# ----------------------------
# Insertion dans la fact table (optionnel)
for rec in fact_records:
    cur.execute("""
        INSERT INTO fact_launch (satellite_key, rocket_key, launch_site_key, date_key, launch_key)
        VALUES (%s, %s, %s, %s, %s)
    """, rec)

# Commit changes
conn.commit()

# %%
# Bulk insert into fact_satellite_launch
execute_values(cur,"INSERT INTO fact_satellite_launch (satellite_key, rocket_key, launch_site_key, date_key, launch_key)VALUES %s", fact_records)

# %%
conn.commit()
cur.close()
conn.close()
